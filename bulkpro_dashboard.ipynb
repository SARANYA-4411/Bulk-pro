# %% [markdown]
# <a href="https://colab.research.google.com/github/SARANYA-4411/Bulk-pro/blob/main/bulkpro_dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tableau dashboard link
#
#
#
# [link text](https://public.tableau.com/views/BULKPRODATA/bulkpro?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# Report link[link text  ](https://drive.google.com/file/d/1DIOz7GYkiZdTID7RiJQRnLFrQYwYU1E2/view?usp=sharing)
#
# drive folder
# [link text](https://drive.google.com/drive/folders/1gi1C3h3V1CPiie45AwxYxiS0hex-7t6c?usp=sharing)

# %% [markdown]
# ![bulkpro.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (29).png](data:image/png;base64,...)
